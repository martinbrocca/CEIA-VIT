# %% [markdown]
# #### Test

# %%
import sys, os
sys.path.append(os.path.abspath('..'))  # apunta al root del proyecto

# %%
from src.evaluation import vision_model_comparison_with_images
# Out:
# ⚠ Using local MLflow at /Users/ari/Desktop/github_repos/CV3/CEIA-VIT/mlruns

# %%
# !python ../src/evaluation/vision_model_comparison_with_images.py --image-folder ../data/raw/food-demo --max-recipes 10000
# Out:
# ⚠ Using local MLflow at /Users/ari/Desktop/github_repos/CV3/CEIA-VIT/mlruns
# Using MPS (Apple Silicon)
# Loading recipes from /Users/ari/Desktop/github_repos/CV3/CEIA-VIT/data/processed/recipes.parquet...
# Loaded 10000 recipes
#
# ============================================================
# Evaluating: CLIP-ViT-B/32
# ============================================================
# Loading model...
# Model loaded in 2.12s
# Creating text embeddings...
# Creating embeddings: 100%|████████████████████| 157/157 [00:31<00:00,  5.05it/s]
# Embeddings created in 31.10s (322 recipes/sec)
# Embedding dimension: 512
# Building index...
#
# Running 10 text evaluation queries...
# Text queries: 100%|█████████████████████████████| 10/10 [00:00<00:00, 23.24it/s]
# Loaded 8 test images
#
# Running 8 vision evaluation queries...
# Vision queries:   0%|                                     | 0/8 [00:00<?, ?it/s]
#   Image: ribs
#   Top match: adam perry lang s secret recipe baby back ribs (score: 0.347)
# Vision queries:  12%|███▋                         | 1/8 [00:00<00:00,  8.13it/s]
#   Image: banana
#   Top match: anemic build your blood with honey and bananas (score: 0.299)
#
#   Image: chocolate_cupcake
#   Top match: a chocolate frosting that rocks (score: 0.323)
#
#   Image: cesar-salad
#   Top match: 24 hour salad (score: 0.350)
#
#   Image: dumplings
#   Top match: a 1 dumplings (score: 0.339)
#
#   Image: letuce
#   Top match: adam s cabbage (score: 0.340)
# Vision queries:  75%|█████████████████████▊       | 6/8 [00:00<00:00, 27.70it/s]
#   Image: indian food
#   Top match: arabian rice aroz mofalfal (score: 0.292)
#
#   Image: cake
#   Top match: american strawberry shortcake (score: 0.352)
# Vision queries: 100%|█████████████████████████████| 8/8 [00:00<00:00, 27.85it/s]
#
# ============================================================
# Evaluating: CLIP-ViT-L/14
# ============================================================
# Loading model...
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["id2label"]` will be overriden.
# Model loaded in 5.82s
# Creating text embeddings...
# Creating embeddings: 100%|████████████████████| 157/157 [00:55<00:00,  2.81it/s]
# Embeddings created in 55.96s (179 recipes/sec)
# Embedding dimension: 768
# Building index...
#
# Running 10 text evaluation queries...
# Text queries: 100%|█████████████████████████████| 10/10 [00:00<00:00, 25.55it/s]
# Loaded 8 test images
#
# Running 8 vision evaluation queries...
# Vision queries:   0%|                                     | 0/8 [00:00<?, ?it/s]
#   Image: ribs
#   Top match: go to bbq sauce for ribs (score: 0.312)
# Vision queries:  12%|███▋                         | 1/8 [00:00<00:01,  5.18it/s]
#   Image: banana
#   Top match: we re going bananas  bread (score: 0.239)
#
#   Image: chocolate_cupcake
#   Top match: almost fat free chocolate cupcakes (score: 0.273)
# Vision queries:  38%|██████████▉                  | 3/8 [00:00<00:00,  8.42it/s]
#   Image: cesar-salad
#   Top match: ann s famous salad (score: 0.265)
#
#   Image: dumplings
#   Top match: a 1 dumplings (score: 0.275)
# Vision queries:  62%|██████████████████▏          | 5/8 [00:00<00:00,  9.46it/s]
#   Image: letuce
#   Top match: ann j s polish sour cream lettuce (score: 0.268)
#
#   Image: indian food
#   Top match: abish (score: 0.247)
# Vision queries:  88%|█████████████████████████▍   | 7/8 [00:00<00:00,  9.96it/s]
#   Image: cake
#   Top match: american strawberry shortcake (score: 0.304)
# Vision queries: 100%|█████████████████████████████| 8/8 [00:00<00:00,  9.46it/s]
#
# ============================================================
# Evaluating: SigLIP-Base
# ============================================================
# Loading model...
# Error evaluating SigLIP-Base: 'siglip'
#
# ================================================================================
# VISION MODEL COMPARISON SUMMARY
# ================================================================================
#
# CLIP-ViT-B/32:
#   Dimension: 512
#   Text Accuracy@5: 0.900
#   Vision Similarity@5: 0.313
#   Speed: 322 recipes/sec
#   Text search: 42.2ms
#   Vision search: 35.6ms
#
# CLIP-ViT-L/14:
#   Dimension: 768
#   Text Accuracy@5: 0.800
#   Vision Similarity@5: 0.260
#   Speed: 179 recipes/sec
#   Text search: 38.2ms
#   Vision search: 105.3ms
#
# ✓ Saved: text_vs_vision_performance.png
# ✓ Saved: text_accuracy_at_k.png
# ✓ Saved: embedding_speed.png
#
# ✓ All charts saved to: /Users/ari/Desktop/github_repos/CV3/CEIA-VIT/experiments/vision_comparison
# /Users/ari/opt/miniconda3/envs/nlp2-env/lib/python3.11/site-packages/mlflow/tracking/_tracking_service/utils.py:140: FutureWarning: Filesystem tracking backend (e.g., './mlruns') is deprecated. Please switch to a database backend (e.g., 'sqlite:///mlflow.db'). For feedback, see: https://github.com/mlflow/mlflow/issues/18534
#   return FileStore(store_uri, store_uri)
# 2025/11/29 16:44:54 INFO mlflow.tracking.fluent: Experiment with name 'recipe-search-pipeline' does not exist. Creating a new experiment.
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# ✓ Logged to MLflow
